# %% [markdown]
# <a href="https://colab.research.google.com/github/alumnosecundaria/digitalizacion/blob/main/temperaturas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio para convertir temperaturas ºCelsius a ºFahrenheit y ºKelvin

# %%
celsius = float(input('Dime la temperatura en ºC: '))
fahrenheit = celsius * (9/5) + 32
kelvin = celsius + 273.15
print('La temperatura de', celsius,'ºC = ',fahrenheit,'ºF')
print('La temperatura de', celsius,'ºC = ',kelvin,'ºK')
# Out:
# Dime la temperatura en ºC: 28.3
# La temperatura de 28.3 ºC =  82.94 ºF
# La temperatura de 28.3 ºC =  301.45 ºK

# %% [markdown]
# Completa el programa anterior para que también convierta los grados Celsius a grados Kelvin
